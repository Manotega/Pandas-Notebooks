# %%
import pandas as pd

df = pd.read_csv('imigrantes_canada.csv')

# %%
df.set_index("País", inplace=True)
anos = list(map(str, range(1980, 2014)))
brasil = df.loc['Brasil', anos]
argentina = df.loc['Argentina', anos]

# %%
dicionario = {
    'anos': brasil.index.tolist(),
    'Brasil': brasil.values.tolist(),
    'Argentina': argentina.values.tolist()
}
dicionario
# Out:
# {'anos': ['1980',
#   '1981',
#   '1982',
#   '1983',
#   '1984',
#   '1985',
#   '1986',
#   '1987',
#   '1988',
#   '1989',
#   '1990',
#   '1991',
#   '1992',
#   '1993',
#   '1994',
#   '1995',
#   '1996',
#   '1997',
#   '1998',
#   '1999',
#   '2000',
#   '2001',
#   '2002',
#   '2003',
#   '2004',
#   '2005',
#   '2006',
#   '2007',
#   '2008',
#   '2009',
#   '2010',
#   '2011',
#   '2012',
#   '2013'],
#  'Brasil': [np.int64(211),
#   np.int64(220),
#   np.int64(192),
#   np.int64(139),
#   np.int64(145),
#   np.int64(130),
#   np.int64(205),
#   np.int64(244),
#   np.int64(394),
#   np.int64(650),
#   np.int64(650),
#   np.int64(877),
#   np.int64(1066),
#   np.int64(866),
#   np.int64(566),
#   np.int64(572),
#   np.int64(586),
#   np.int64(591),
#   np.int64(531),
#   np.int64(626),
#   np.int64(845),
#   np.int64(847),
#   np.int64(745),
#   np.int64(839),
#   np.int64(917),
#   np.int64(969),
#   np.int64(1181),
#   np.int64(1746),
#   np.int64(2138),
# ...

# %%
df = pd.DataFrame(dicionario)
df.head()
# Out:
#    anos  Brasil  Argentina
# 0  1980     211        368
# 1  1981     220        426
# 2  1982     192        626
# 3  1983     139        241
# 4  1984     145        237

# %%
import matplotlib.pyplot as plt

# %%
plt.title('Imigracao para o Canada')
plt.xlabel('Ano')
plt.ylabel('Numero de imigrantes')
plt.plot(df['anos'], df['Brasil'], df['Argentina'])
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010', '2013'])
plt.legend(['Brasil', 'Argentina'])
plt.show()

# %% [markdown]
# <h1>LOJAS</h1>

# %%
lojas = ['A', 'B', 'C', 'D']

vendas_2022 = {'Jan': [100, 80, 150, 50],
    'Fev': [120, 90, 170, 60],
    'Mar': [150, 100, 200, 80],
    'Abr': [180, 110, 230, 90],
    'Mai': [220, 190, 350, 200],
    'Jun': [230, 150, 280, 120],
    'Jul': [250, 170, 300, 140],
    'Ago': [260, 180, 310, 150],
    'Set': [240, 160, 290, 130],
    'Out': [220, 140, 270, 110],
    'Nov': [400, 220, 350, 190],
    'Dez': [300, 350, 400, 250]
}

vendas = pd.DataFrame(vendas_2022, index=lojas)
vendas
# Out:
#    Jan  Fev  Mar  Abr  Mai  Jun  Jul  Ago  Set  Out  Nov  Dez
# A  100  120  150  180  220  230  250  260  240  220  400  300
# B   80   90  100  110  190  150  170  180  160  140  220  350
# C  150  170  200  230  350  280  300  310  290  270  350  400
# D   50   60   80   90  200  120  140  150  130  110  190  250

# %%
import matplotlib.pyplot as plt

# %%
fig, axs = plt.subplots(2, 2, figsize=(20,10))
fig.subplots_adjust(hspace=0.3)
fig.suptitle('Vendas das principais lojas em 2022')

axs[0, 0].plot(vendas.loc['A'], color='blue')
axs[0, 0].set_title('Loja A')

axs[0, 1].plot(vendas.loc['B'], color='red')
axs[0, 1].set_title('Loja B')

axs[1, 0].plot(vendas.loc['C'], color='green')
axs[1, 0].set_title('Loja C')

axs[1, 1].plot(vendas.loc['D'], color='yellow')
axs[1, 1].set_title('Loja D')

ymin = 0
ymax = 450
for ax in axs.ravel():
    ax.set_ylim(ymin, ymax)

for ax in axs.flat:
    ax.set_xlabel('Mes')
    ax.set_ylabel('Total de vendas')

plt.show()
